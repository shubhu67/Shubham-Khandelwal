# %% [markdown]
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon
#
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import numpy as np
import pandas as pd

# %%
ecom=pd.read_csv('Ecommerce Purchases')
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom.tail(4)
# Out:
#                                                 Address    Lot AM or PM  \
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# 9997              Anderson Ltd  6011539787356311       05/21
# 9998                  Cook Inc   180003348082930       11/17
# 9999                Greene Inc  4139972901927273       02/19
#
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.shape
# Out:
# (10000, 14)

# %%
ecom.shape[0]
# Out:
# 10000

# %%
ecom.shape[1]
# Out:
# 16

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# exp_yr              0
# Email_providers     0
# dtype: int64

# %% [markdown]
# #### % of missing values

# %%
(ecom.isnull().sum()/ecom.shape[0])*100
# Out:
# Address             0.0
# Lot                 0.0
# AM or PM            0.0
# Browser Info        0.0
# Company             0.0
# Credit Card         0.0
# CC Exp Date         0.0
# CC Security Code    0.0
# CC Provider         0.0
# Email               0.0
# Job                 0.0
# IP Address          0.0
# Language            0.0
# Purchase Price      0.0
# exp_yr              0.0
# Email_providers     0.0
# dtype: float64

# %%
ecom['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
np.mean(ecom['Purchase Price'])
# Out:
# 50.34730200000025

# %%
ecom['Purchase Price'].mean(skipna=True)
# Out:
# 50.34730200000025

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
print(ecom['Purchase Price'].max()
print(ecom['Purchase Price'].min()
# Out:
# 99.99
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
ecom['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
list(ecom['Language'].values
# Out:
# ['el',
#  'fr',
#  'de',
#  'es',
#  'es',
#  'ru',
#  'de',
#  'pt',
#  'ru',
#  'zh',
#  'el',
#  'en',
#  'en',
#  'it',
#  'de',
#  'el',
#  'de',
#  'el',
#  'el',
#  'fr',
#  'de',
#  'it',
#  'en',
#  'ru',
#  'es',
#  'de',
#  'en',
#  'es',
#  'es',
#  'it',
#  'ru',
#  'en',
#  'pt',
#  'ru',
#  'pt',
#  'zh',
#  'zh',
#  'es',
#  'en',
#  'el',
#  'pt',
#  'ru',
#  'de',
#  'el',
#  'en',
#  'es',
#  'pt',
#  'it',
#  'ru',
#  'es',
#  'de',
#  'es',
#  'it',
#  'fr',
#  'en',
#  'pt',
#  'el',
#  'es',
#  'el',
#  'zh',
#  'de',
#  'el',
#  'de',
#  'de',
#  'it',
#  'pt',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'ru',
#  'it',
#  'pt',
#  'el',
#  'zh',
#  'zh',
#  'fr',
#  'en',
#  'el',
#  'zh',
#  'it',
#  'it',
#  'fr',
#  'it',
#  'fr',
#  'el',
#  'de',
#  'ru',
#  'zh',
#  'el',
#  'es',
#  'fr',
#  'zh',
#  'es',
#  'en',
#  'fr',
#  'fr',
#  'ru',
#  'fr',
#  'fr',
#  'el',
#  'ru',
#  'ru',
#  'it',
#  'it',
#  'en',
#  'ru',
#  'es',
#  'pt',
#  'fr',
#  'it',
# ...

# %%
ecom[(ecom['Language']=='en') | (ecom['Language']=='fr')].shape[0]
# Out:
# 2195

# %%
ecom[ecom['Language']=='en'].shape[0]
# Out:
# 1098

# %%
ecom[ecom['Language']=='en'].shape[0]
# Out:
# 1098

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
ecom[ecom['Job']=='Lawyer'].shape[0]
# Out:
# 30

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['AM or PM'].value_counts().loc['PM']
# Out:
# 5068

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
ecom['Job'].value_counts().sort_values(ascending=False).head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom.loc[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price'].loc[513]
# Out:
# 75.1

# %%
ecom[ecom['Lot']=='90 WT']
# Out:
#                                                Address    Lot AM or PM  \
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
#
#                                           Browser Info     Company  \
# 513  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like M...  Bright PLC
#
#       Credit Card CC Exp Date  CC Security Code       CC Provider  \
# 513  630438419693       11/19               173  American Express
#
#                 Email              Job     IP Address Language  \
# 513  jesse00@page.net  Energy engineer  156.70.208.94       ru
#
#      Purchase Price  exp_yr Email_providers
# 513            75.1      19        page.net

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom[ecom['Credit Card']==4926535242672853]['Email'].iloc[0]
# Out:
# 'bondellen@williams-garza.com'

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom[(ecom['CC Provider']=='American Express')&(ecom['Purchase Price']>95)].shape[0]
# Out:
# 39

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
ecom['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
ecom['exp_yr']=ecom['CC Exp Date'].apply(lambda x:x.split('/')[1])
ecom['exp_yr']
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: exp_yr, Length: 10000, dtype: object

# %%
ecom['exp_yr']=ecom['CC Exp Date'].apply(lambda x:int(x.split('/')[1]))
ecom['exp_yr']
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: exp_yr, Length: 10000, dtype: int64

# %%
ecom[ecom['exp_yr']==25].shape[0]
# Out:
# 1033

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
ecom['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
ecom['Email_providers']=ecom['Email'].apply(lambda x:x.split('@')[1])
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom['Email_providers'].dtype
# Out:
# dtype('O')

# %%
ecom['Email_providers'].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email_providers, dtype: int64

# %% [markdown]
# # Great Job!
